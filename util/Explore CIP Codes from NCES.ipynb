# %% [markdown]
# # Classifications
#
# [Legacy Classifications](http://nces.ed.gov/pubs2002/cip2000/xls/cip.zip)
#
# (Also has legacy crosswalks)
#
# [2010 Classifications](https://nces.ed.gov/ipeds/cipcode/Files/CIPCode2010.csv)
#
# [2020 Classifications](https://nces.ed.gov/ipeds/cipcode/Files/CIPCode2020.csv)
#
# # Crosswalks
#
# [2000 to 2010](https://nces.ed.gov/ipeds/cipcode/Files/Crosswalk2000to2010.csv)
#
# [2010 to 2020](https://nces.ed.gov/ipeds/cipcode/Files/Crosswalk2010to2020.csv)

# %%
import pandas as pd
import numpy as np
from io import BytesIO
from zipfile import ZipFile
from urllib.request import urlopen
from database.cip_history import CipCode

# import user_functions

def clean_string(text: str):
    """ strips Excel formula text and trailing periods """
    text = str(text)
    if text[:1] == '=':
        text = text[2:-1]
    if str(text).endswith('.'):
        text = text[:-1]
    return(text)

class CipFile:
    """ Class for a particular year's CIP assignments """
    def __init__(self, year: int):
        """ class constructor """
        self.year = year
        self.data = list()
        
        if self.year < 2010:
            with urlopen('http://nces.ed.gov/pubs2002/cip2000/xls/cip.zip') as resp:
                zipfile = ZipFile(BytesIO(resp.read()))
                file_name = zipfile.namelist()[0]

                with zipfile.open(file_name) as data_file:
                    df = pd.read_excel(
                        io = data_file,
                        sheet_name = f'CIP{self.year}',
                        index_col = None,
                        dtype = object)
            
            df = df.rename(columns = {
                'CIP85': 'cipcode',
                'CIP90': 'cipcode',
                'CIPDESCR': 'cipdefinition'
            })
            
            if self.year == 1985:
                df['cipdefinition'] = 'Unknown'
            elif self.year == 2000:
                df = df.query('CIPCode != "-----"')
                # df.cipcode = np.where(df.cipcode == '-----', df.reportunder, df.cipcode)

        else:
            df = pd.read_csv(
                f'https://nces.ed.gov/ipeds/cipcode/Files/CIPCode{year}.csv',
                dtype = object,
                index_col = None,
                low_memory = False,
                encoding = "iso-8859-1")
            
        df.columns = df.columns.str.strip().str.lower()
        
        cols = ['cipcode', 'cipfamily', 'ciptitle', 'cipdefinition']
        df = df[cols]
        df = df.applymap(clean_string)
        
        for row in df.itertuples(index=False):
            self.data.append(
                CipCode(
                    cipcode = row.cipcode,
                    version = self.year,
                    title = row.ciptitle,
                    description = row.cipdefinition,
                    family = row.cipfamily,
                    ))


    @property
    def year(self):
        """ return year value """
        return self.__year
    
    @year.setter
    def year(self, year: int):
        """ set year value """
        self.__year = year
        
    def __repr__(self):
        """ class repr method """
        return f'{self.__class__.__name__}(year={self.__year!r})'

# %%
for year in [1985, 1990, 2000, 2010, 2020]:
    _cip = CipFile(year)
    print(f'CIP Codes for: {_cip.year}')
    print(f'{_cip.data[:5]}\n')
# Out:
# CIP Codes for: 1985
# [CipCode(cipcode='00.0000', version=1985, title='Not Applicable', description='Unknown', family='00'), CipCode(cipcode='01.0101', version=1985, title='Agric Bus & Mgmt, Genl', description='Unknown', family='01'), CipCode(cipcode='01.0103', version=1985, title='Agricultural Economics', description='Unknown', family='01'), CipCode(cipcode='01.0199', version=1985, title='Agric Bus & Mgmt, Other', description='Unknown', family='01'), CipCode(cipcode='01.0201', version=1985, title='Agricul Mechanics, Genl', description='Unknown', family='01')]
#
# CIP Codes for: 1990
# [CipCode(cipcode='01.0000', version=1990, title='Agricultural Business and Production', description='A summary of groups of instructional programs that prepare individuals to apply scientific knowledge and methods, and techniques to agricultural business and production', family='01'), CipCode(cipcode='01.0100', version=1990, title='Agricultural Business & Management', description='A group of instructional programs that generally prepares individuals to apply modern economic and business principles involved in the organization, operation and management of farm and agricultural businesses', family='01'), CipCode(cipcode='01.0101', version=1990, title='Agricultural Business & Management, General', description='An instructional program that generally prepares individuals to apply modern economic and business principles involved in the organization, operation and management of farm and agricultural businesses', family='01'), CipCode(cipcode='01.0102', version=1990, title='Agricultural Business/Agribusiness Operations', description='An instructional program that prepares individuals to apply modern business and economic principles relating to the production and marketing of agricultural products and services', family='01'), CipCode(cipcode='01.0103', version=1990, title='Agricultural Economics', description='An instructional program that describes modern business and economic principles relating to the allocation of resources in the production and marketing of agricultural products and services in the domestic and international markets', family='01')]
#
# CIP Codes for: 2000
# [CipCode(cipcode='03.03', version=2000, title='Fishing and Fisheries Sciences and Management', description='Instructional content is defined in code 03.0301', family='03'), CipCode(cipcode='03.0301', version=2000, title='Fishing and Fisheries Sciences and Management', description='A program that focuses on the scientific study of the husbandry and production of non-domesticated fish and shellfish populations for recreational and commercial purposes and the management of fishing and marine/aquatic product processing to ensure adequate conservation and efficient utilization.  Includes instruction in the principles of marine/aquatic biology, freshwater and saltwater ecosystems, water resources, fishing production operations and management, fishing policy and regulation, and the management of recreational and commercial fishing activities', family='03'), CipCode(cipcode='03.04', version=2000, title='Forest Production and Processing', description='(Deleted)', family='03'), CipCode(cipcode='03.0401', version=2000, title='Forest Harvesting and Production Technology/Technician', description='(Deleted, Report under 03.0511)', family='03'), CipCode(cipcode='03.0404', version=2000, title='Forest Products Technology/Technician', description='(Deleted, Report under 03.0511)', family='03')]
#
# CIP Codes for: 2010
# [CipCode(cipcode='01', version=2010, title='AGRICULTURE, AGRICULTURE OPERATIONS, AND RELATED SCIENCES', description='Instructional programs that focus on agriculture and related sciences and that prepare individuals to apply specific knowledge, methods, and techniques to the management and performance of agricultural operations', family='01'), CipCode(cipcode='01.00', version=2010, title='Agriculture, General', description='Instructional content is defined in code 01.0000', family='01'), CipCode(cipcode='01.0000', version=2010, title='Agriculture, General', description='A program that focuses on the general principles and practice of agricultural research and production and that may prepare individuals to apply this knowledge to the solution of practical agricultural problems.  Includes instruction in basic animal, plant, and soil science; animal husbandry and plant cultivation; soil conservation; and agricultural operations such as farming, ranching, and agricultural business', family='01'), CipCode(cipcode='01.01', version=2010, title='Agricultural Business and Management', description='Instructional content for this group of programs is defined in codes 01.0101 - 01.0199', family='01'), CipCode(cipcode='01.0101', version=2010, title='Agricultural Business and Management, General', description='A  general program that focuses on modern business and economic principles involved in the organization, operation, and management of agricultural enterprises', family='01')]
#
# CIP Codes for: 2020
# [CipCode(cipcode='01', version=2020, title='AGRICULTURAL/ANIMAL/PLANT/VETERINARY SCIENCE AND RELATED FIELDS', description='Instructional programs that focus on agriculture, animal, plant, veterinary, and related sciences and that prepares individuals to apply specific knowledge, methods, and techniques to the management and performance of agricultural and veterinary operations', family='01'), CipCode(cipcode='01.00', version=2020, title='Agriculture, General', description='Instructional content is defined in code 01.0000', family='01'), CipCode(cipcode='01.0000', version=2020, title='Agriculture, General', description='A program that focuses on the general principles and practice of agricultural research and production and that may prepare individuals to apply this knowledge to the solution of practical agricultural problems.  Includes instruction in basic animal, plant, and soil science; animal husbandry and plant cultivation; soil conservation; and agricultural operations such as farming, ranching, and agricultural business', family='01'), CipCode(cipcode='01.01', version=2020, title='Agricultural Business and Management', description='Instructional content for this group of programs is defined in codes 01.0101 - 01.0199', family='01'), CipCode(cipcode='01.0101', version=2020, title='Agricultural Business and Management, General', description='A  general program that focuses on modern business and economic principles involved in the organization, operation, and management of agricultural enterprises', family='01')]

# %%
raw_data = pd.DataFrame()

for year in (2010, 2020):
    df = pd.read_csv(
        f'https://nces.ed.gov/ipeds/cipcode/Files/CIPCode{year}.csv',
        dtype = object)
    df['year'] = year
    print(f'{df.shape[0]} rows read.')
    raw_data = pd.concat([raw_data, df])

raw_data
# Out:
# 2318 rows read.
# 2847 rows read.
#      CIPFamily     CIPCode                  Action TextChange  \
# 0        ="01"       ="01"  No substantive changes         no
# 1        ="01"    ="01.00"  No substantive changes         no
# 2        ="01"  ="01.0000"  No substantive changes         no
# 3        ="01"    ="01.01"  No substantive changes         no
# 4        ="01"  ="01.0101"  No substantive changes         no
# ...        ...         ...                     ...        ...
# 2842     ="61"  ="61.2801"                Moved to        yes
# 2843     ="61"  ="61.2802"                Moved to        yes
# 2844     ="61"  ="61.2899"                     New         no
# 2845     ="61"    ="61.99"                     New         no
# 2846     ="61"  ="61.9999"                     New         no
#
#                                                CIPTitle  \
# 0     AGRICULTURE, AGRICULTURE OPERATIONS, AND RELAT...
# 1                                 Agriculture, General.
# 2                                 Agriculture, General.
# 3                 Agricultural Business and Management.
# 4        Agricultural Business and Management, General.
# ...                                                 ...
# 2842                         Urology Residency Program.
# 2843              Pediatric Urology Fellowship Program.
# 2844      Urology Residency/Fellowship Programs, Other.
# 2845      Medical Residency/Fellowship Programs, Other.
# 2846      Medical Residency/Fellowship Programs, Other.
#
#                                           CIPDefinition  \
# 0     Instructional programs that focus on agricultu...
# 1     Instructional content is defined in code 01.0000.
# 2     A program that focuses on the general principl...
# 3     Instructional content for this group of progra...
# 4     A  general program that focuses on modern busi...
# ...                                                 ...
# 2842  A residency training program that prepares phy...
# 2843  A fellowship training program that prepares in...
# 2844  Any residency or fellowship program in urology...
# 2845  Instructional content is defined in code 61.9999.
# 2846  Any medical residency or fellowship program no...
#
#                           CrossReferences Examples  year
# 0                                     NaN      NaN  2010
# 1                                     NaN      NaN  2010
# 2     14.0301 - Agricultural Engineering.      NaN  2010
# 3                                     NaN      NaN  2010
# 4                                     NaN      NaN  2010
# ...                                   ...      ...   ...
# 2842                                  NaN      NaN  2020
# 2843                                  NaN      NaN  2020
# 2844                                  NaN      NaN  2020
# 2845                                  NaN      NaN  2020
# 2846                                  NaN      NaN  2020
#
# [5165 rows x 9 columns]

# %%
cip = df.apply(lambda x: x.map(clean_string) if x.name in ['CIPCode', 'CIPFamily'] else x)

# %%
unique = cip[['CIPCode', 'year']].groupby(['CIPCode']).max()

unique
# Out:
#          year
# CIPCode
# 01       2020
# 01.00    2020
# 01.0000  2020
# 01.01    2020
# 01.0101  2020
# ...       ...
# 61.2801  2020
# 61.2802  2020
# 61.2899  2020
# 61.99    2020
# 61.9999  2020
#
# [2847 rows x 1 columns]

# %%
new_cip = cip.merge(
    right=unique,
    how = 'inner',
    on=['CIPCode', 'year']
)

new_cip
# Out:
#      CIPFamily  CIPCode                  Action TextChange  \
# 0           01       01  No substantive changes        yes
# 1           01    01.00  No substantive changes         no
# 2           01  01.0000  No substantive changes         no
# 3           01    01.01  No substantive changes         no
# 4           01  01.0101  No substantive changes         no
# ...        ...      ...                     ...        ...
# 2842        61  61.2801                Moved to        yes
# 2843        61  61.2802                Moved to        yes
# 2844        61  61.2899                     New         no
# 2845        61    61.99                     New         no
# 2846        61  61.9999                     New         no
#
#                                                CIPTitle  \
# 0     AGRICULTURAL/ANIMAL/PLANT/VETERINARY SCIENCE A...
# 1                                 Agriculture, General.
# 2                                 Agriculture, General.
# 3                 Agricultural Business and Management.
# 4        Agricultural Business and Management, General.
# ...                                                 ...
# 2842                         Urology Residency Program.
# 2843              Pediatric Urology Fellowship Program.
# 2844      Urology Residency/Fellowship Programs, Other.
# 2845      Medical Residency/Fellowship Programs, Other.
# 2846      Medical Residency/Fellowship Programs, Other.
#
#                                           CIPDefinition  \
# 0     Instructional programs that focus on agricultu...
# 1     Instructional content is defined in code 01.0000.
# 2     A program that focuses on the general principl...
# 3     Instructional content for this group of progra...
# 4     A  general program that focuses on modern busi...
# ...                                                 ...
# 2842  A residency training program that prepares phy...
# 2843  A fellowship training program that prepares in...
# 2844  Any residency or fellowship program in urology...
# 2845  Instructional content is defined in code 61.9999.
# 2846  Any medical residency or fellowship program no...
#
#                           CrossReferences Examples  year
# 0                                     NaN      NaN  2020
# 1                                     NaN      NaN  2020
# 2     14.0301 - Agricultural Engineering.      NaN  2020
# 3                                     NaN      NaN  2020
# 4                                     NaN      NaN  2020
# ...                                   ...      ...   ...
# 2842                                  NaN      NaN  2020
# 2843                                  NaN      NaN  2020
# 2844                                  NaN      NaN  2020
# 2845                                  NaN      NaN  2020
# 2846                                  NaN      NaN  2020
#
# [2847 rows x 9 columns]
