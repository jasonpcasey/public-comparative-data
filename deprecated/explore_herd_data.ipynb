# %%
# coding=utf-8
# %config InlineBackend.figure_format ='retina'
# %matplotlib inline

import numpy as np
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

pd.set_option('display.max_rows', 10)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# Set theme
sns.set_style('darkgrid')

# constants
year = 2011

state_fips = {'AK': 2, 'AL': 1, 'AR': 5, 'AS': 60, 'AZ': 4, 'CA': 6, 'CO': 8, 'CT': 9, 'DC': 11,
              'DE': 10, 'FL': 12, 'GA': 13, 'GU': 66, 'HI': 15, 'IA': 19, 'ID': 16, 'IL': 17,
              'IN': 18, 'KS': 20, 'KY': 21, 'LA': 22, 'MA': 25, 'MD': 24, 'ME': 23, 'MI': 26,
              'MN': 27, 'MO': 29, 'MS': 28, 'MT': 30, 'NC': 37, 'ND': 38, 'NE': 31, 'NH': 33,
              'NJ': 34, 'NM': 35, 'NV': 32, 'NY': 36, 'OH': 39, 'OK': 40, 'OR': 41, 'PA': 42,
              'PR': 72, 'RI': 44, 'SC': 45, 'SD': 46, 'TN': 47, 'TX': 48, 'UT': 49, 'VA': 51,
              'VI': 78, 'VT': 50, 'WA': 53, 'WI': 55, 'WV': 54, 'WY': 56, 'all': -1}

big_10 = [145637, 147767, 151351, 153658, 163286, 170976, 171100,
          174066, 181464, 186380, 204796, 214777, 240444, 243780]

regents = [181464, 153658, 153603, 126614,
           126818, 145637, 155317, 174066,
           178396, 204796, 243780]

# local functions
def item_recode(col, codings, default_value = None):
    if default_value == None:
        answer = col.map(codings, na_action = 'ignore')
    else:
        answer = col.map(codings, na_action = 'ignore').fillna(default_value)  
    return(answer)

# %%
try:
    spec = 'data/nsf_{}.pickle'.format(year)
    print('Reading data for fiscal year ending {}:\n\t{}... '.format(year, spec), end='', flush=True)
    with open(spec, 'rb') as f:
        herd = pickle.load(f)
except Exception as e:
    print('ERROR.\nFile not downloaded properly.\n\n{}\n'.format(str(e)))
else:
    print('DONE.')
    herd.info()
# Out:
# Reading data for fiscal year ending 2011:
# 	data/nsf_2011.pickle... DONE.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263977 entries, 0 to 263976
# Data columns (total 23 columns):
# inst_id                      263977 non-null int32
# year                         263977 non-null int16
# ncses_inst_id                260216 non-null object
# ipeds_unitid                 251188 non-null float32
# hbcu_flag                    263977 non-null bool
# med_sch_flag                 263977 non-null object
# hhe_flag                     263977 non-null bool
# toi_code                     263977 non-null int8
# hdg_code                     263977 non-null int8
# toc_code                     263977 non-null int8
# inst_name_long               263977 non-null object
# inst_city                    263977 non-null object
# inst_state_code              263977 non-null object
# inst_zip                     263740 non-null object
# questionnaire_no             263977 non-null object
# question                     263977 non-null object
# row                          263977 non-null object
# column                       243483 non-null object
# data                         263977 non-null float32
# status                       22270 non-null object
# othinfo                      3014 non-null object
# othinfo_s                    0 non-null object
# standardized_agency_names    3008 non-null object
# dtypes: bool(2), float32(2), int16(1), int32(1), int8(3), object(14)
# memory usage: 33.0+ MB

# %%
# set date key
date_key = '{}-06-30'.format(year)

# modify data frame to apply needed fixes
herd['date_key'] = date_key

herd['med_sch_flag'] = herd.med_sch_flag.isin(['T','TRUE', 'True', 'true', 't', 'Y', 'Yes', '1'])

herd['toi_code'] = herd.toi_code == 1

toc = {1: 'Public',
       2: 'Private'}

herd['toc_code'] = item_recode(herd['toc_code'], toc, 'Unknown')
herd['inst_state_code'] = item_recode(herd['inst_state_code'], state_fips, -1)

herd.ipeds_unitid = herd.ipeds_unitid.fillna(-1).astype(int)
herd.ncses_inst_id = herd.ncses_inst_id.fillna('XXXXXXXX')

herd['data'] = herd.data.fillna(0) * 1000

herd = herd.rename(columns = {'inst_name_long': 'institution_name',
                              'ipeds_unitid': 'unitid',
                              'inst_state_code': 'state_fips',
                              'toc_code': 'control',
                              'toi_code': 'academic_institution',
                              'med_sch_flag': 'medical_school_flag',
                              'hbcu_flag': 'hbcu'})

herd
# Out:
#         inst_id  year ncses_inst_id  unitid   hbcu  medical_school_flag  \
# 0           166  2011      U0626001  111966  False                 True
# 1           166  2011      U0626001  111966  False                 True
# 2           166  2011      U0626001  111966  False                 True
# 3           166  2011      U0626001  111966  False                 True
# 4           166  2011      U0626001  111966  False                 True
# ...         ...   ...           ...     ...    ...                  ...
# 263972   353086  2011      XXXXXXXX      -1  False                 True
# 263973   353086  2011      XXXXXXXX      -1  False                 True
# 263974   353086  2011      XXXXXXXX      -1  False                 True
# 263975   353086  2011      XXXXXXXX      -1  False                 True
# 263976   353086  2011      XXXXXXXX      -1  False                 True
#
#         hhe_flag  academic_institution  hdg_code  control  ...  \
# 0           True                  True         2  Private  ...
# 1           True                  True         2  Private  ...
# 2           True                  True         2  Private  ...
# 3           True                  True         2  Private  ...
# 4           True                  True         2  Private  ...
# ...          ...                   ...       ...      ...  ...
# 263972     False                  True         1  Private  ...
# 263973     False                  True         1  Private  ...
# 263974     False                  True         1  Private  ...
# 263975     False                  True         1  Private  ...
# 263976     False                  True         1  Private  ...
#
#        questionnaire_no                                           question  \
# 0                  01.a                                             Source
# 1                  01.e                                             Source
# 2                  01.g                                             Source
# 3                    03                                Externally financed
# 4                    03                                Externally financed
# ...                 ...                                                ...
# 263972            14H06  Capitalized equipment expenditures by field an...
# 263973              14K  Capitalized equipment expenditures by field an...
# 263974              14K  Capitalized equipment expenditures by field an...
# 263975              14K  Capitalized equipment expenditures by field an...
# 263976            NA_01                                         ARRA funds
#
#                                                  row      column        data  \
# 0                                 Federal government         NaN  20679000.0
# 1                                  Institution funds         NaN   1471000.0
# 2                                              Total         NaN  22150000.0
# 3       Grants, reimbursements, and other agreements         NaN  20679000.0
# 4                                              Total         NaN  20679000.0
# ...                                              ...         ...         ...
# 263972                          Social sciences, all       Total     40000.0
# 263973                                           All     Federal  18273000.0
# 263974                                           All  Nonfederal   1636000.0
# 263975                                           All       Total  19909000.0
# 263976                                         Total         NaN  67685000.0
#
#        status othinfo othinfo_s  standardized_agency_names    date_key
# 0         NaN     NaN       NaN                        NaN  2011-06-30
# 1         NaN     NaN       NaN                        NaN  2011-06-30
# 2         NaN     NaN       NaN                        NaN  2011-06-30
# 3         NaN     NaN       NaN                        NaN  2011-06-30
# 4         NaN     NaN       NaN                        NaN  2011-06-30
# ...       ...     ...       ...                        ...         ...
# 263972    NaN     NaN       NaN                        NaN  2011-06-30
# 263973    NaN     NaN       NaN                        NaN  2011-06-30
# 263974    NaN     NaN       NaN                        NaN  2011-06-30
# 263975    NaN     NaN       NaN                        NaN  2011-06-30
# 263976    NaN     NaN       NaN                        NaN  2011-06-30
#
# [263977 rows x 24 columns]

# %%
herd[['questionnaire_no', 'question']].groupby(by=['questionnaire_no', 'question']).count()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(01.a, Source), (01.b, Source), (01.c, Source), (01.d, Source), (01.e, Source), (01.f, Source), (01.g, Source), (02.f, Foreign funds), (03, Externally financed), (04, Medical school expenditures), (05, Clinical trials), (06.a, Type of R&D conducted), (06.b, Type of R&D conducted), (06.c, Type of R&D conducted), (06.d, Type of R&D conducted), (07.a, Received as a subrecipient), (07.b, Received as a subrecipient), (07.c, Received as a subrecipient), (07.d, Received as a subrecipient), (07.e, Received as a subrecipient), (07.e, Received as subrecipient), (08.a, Passed through to subrecipients), (08.b, Passed through to subrecipients), (08.c, Passed through to subrecipients), (08.d, Passed through to subrecipients), (08.e, Passed through to subrecipients), (09A, Federal expenditures by field and agency), (09B01, Federal expenditures by field and agency), (09B02, Federal expenditures by field and agency), (09B03, Federal expenditures by field and agency), (09B04, Federal expenditures by field and agency), (09B05, Federal expenditures by field and agency), (09B07, Federal expenditures by field and agency), (09B08, Federal expenditures by field and agency), (09B09, Federal expenditures by field and agency), (09B10, Federal expenditures by field and agency), (09C01, Federal expenditures by field and agency), (09C02, Federal expenditures by field and agency), (09C03, Federal expenditures by field and agency), (09C04, Federal expenditures by field and agency), (09C05, Federal expenditures by field and agency), (09D01, Federal expenditures by field and agency), (09D02, Federal expenditures by field and agency), (09D03, Federal expenditures by field and agency), (09D05, Federal expenditures by field and agency), (09D06, Federal expenditures by field and agency), (09E, Federal expenditures by field and agency), (09F01, Federal expenditures by field and agency), (09F02, Federal expenditures by field and agency), (09F04, Federal expenditures by field and agency), (09F05, Federal expenditures by field and agency), (09F06, Federal expenditures by field and agency), (09G, Federal expenditures by field and agency), (09H02, Federal expenditures by field and agency), (09H03, Federal expenditures by field and agency), (09H04, Federal expenditures by field and agency), (09H05, Federal expenditures by field and agency), (09H06, Federal expenditures by field and agency), (09I, Federal expenditures by field and agency), (09J01, Federal expenditures by field and agency), (09J02, Federal expenditures by field and agency), (09J03, Federal expenditures by field and agency), (09J04, Federal expenditures by field and agency), (09J05, Federal expenditures by field and agency), (09J06, Federal expenditures by field and agency), (09J07, Federal expenditures by field and agency), (09J08, Federal expenditures by field and agency), (09J09, Federal expenditures by field and agency), (09K, Federal expenditures by field and agency), (10, Other agency specified), (11A, Nonfederal expenditures by field and source), (11B01, Nonfederal expenditures by field and source), (11B02, Nonfederal expenditures by field and source), (11B03, Nonfederal expenditures by field and source), (11B04, Nonfederal expenditures by field and source), (11B05, Nonfederal expenditures by field and source), (11B07, Nonfederal expenditures by field and source), (11B08, Nonfederal expenditures by field and source), (11B09, Nonfederal expenditures by field and source), (11B10, Nonfederal expenditures by field and source), (11C01, Nonfederal expenditures by field and source), (11C02, Nonfederal expenditures by field and source), (11C03, Nonfederal expenditures by field and source), (11C04, Nonfederal expenditures by field and source), (11C05, Nonfederal expenditures by field and source), (11D01, Nonfederal expenditures by field and source), (11D02, Nonfederal expenditures by field and source), (11D03, Nonfederal expenditures by field and source), (11D05, Nonfederal expenditures by field and s ...
#
# [167 rows x 0 columns]
